# %%
import pandas as pd

file_path = "../data/raw/Hospital Data Analysis.csv"

df = pd.read_csv(file_path)

df.head()
# Out:
#    Patient_ID  Age  Gender      Condition                 Procedure   Cost  \
# 0           1   45  Female  Heart Disease               Angioplasty  15000
# 1           2   60    Male       Diabetes           Insulin Therapy   2000
# 2           3   32  Female  Fractured Arm          X-Ray and Splint    500
# 3           4   75    Male         Stroke    CT Scan and Medication  10000
# 4           5   50  Female         Cancer  Surgery and Chemotherapy  25000
#
#    Length_of_Stay Readmission    Outcome  Satisfaction
# 0               5          No  Recovered             4
# 1               3         Yes     Stable             3
# 2               1          No  Recovered             5
# 3               7         Yes     Stable             2
# 4              10          No  Recovered             4

# %%
df .shape
# Out:
# (984, 10)

# %%
df .isnull().sum()
# Out:
# Patient_ID        0
# Age               0
# Gender            0
# Condition         0
# Procedure         0
# Cost              0
# Length_of_Stay    0
# Readmission       0
# Outcome           0
# Satisfaction      0
# dtype: int64

# %%
df .duplicated().sum()
# Out:
# np.int64(0)

# %%
df .dtypes
# Out:
# Patient_ID        int64
# Age               int64
# Gender              str
# Condition           str
# Procedure           str
# Cost              int64
# Length_of_Stay    int64
# Readmission         str
# Outcome             str
# Satisfaction      int64
# dtype: object

# %%
for col in ["Gender", "Condition", "Procedure", "Readmission", "Outcome"]:
    print(f"\n{col}:")
    print(df[col].unique())
# Out:
# Gender:
# <StringArray>
# ['Female', 'Male']
# Length: 2, dtype: str
#
# Condition:
# <StringArray>
# [        'Heart Disease',              'Diabetes',         'Fractured Arm',
#                 'Stroke',                'Cancer',          'Hypertension',
#           'Appendicitis',         'Fractured Leg',          'Heart Attack',
#      'Allergic Reaction', 'Respiratory Infection',       'Prostate Cancer',
#             'Childbirth',         'Kidney Stones',        'Osteoarthritis']
# Length: 15, dtype: str
#
# Procedure:
# <StringArray>
# [                         'Angioplasty',
#                       'Insulin Therapy',
#                      'X-Ray and Splint',
#                'CT Scan and Medication',
#              'Surgery and Chemotherapy',
#             'Medication and Counseling',
#                          'Appendectomy',
#             'Cast and Physical Therapy',
#               'Cardiac Catheterization',
#                 'Epinephrine Injection',
# ...

# %%
print("Readmission:")
print(df["Readmission"].value_counts())

print("\nOutcome:")
print(df["Outcome"].value_counts())

print("\nSatisfaction:")
print(df["Satisfaction"].value_counts().sort_index())
# Out:
# Readmission:
# Readmission
# No     720
# Yes    264
# Name: count, dtype: int64
#
# Outcome:
# Outcome
# Recovered    591
# Stable       393
# Name: count, dtype: int64
#
# Satisfaction:
# Satisfaction
# 2    133
# 3    261
# 4    458
# 5    132
# Name: count, dtype: int64

# %%
print("Total rows:", len(df))
print("\nReadmission total:")
print(df["Readmission"].value_counts().sum())

print("\nOutcome total:")
print(df["Outcome"].value_counts().sum())

print("\nSatisfaction total:")
print(df["Satisfaction"].value_counts().sum())
# Out:
# Total rows: 984
#
# Readmission total:
# 984
#
# Outcome total:
# 984
#
# Satisfaction total:
# 984

# %%
print("Age:")
print(df["Age"].describe())

print("\nCost:")
print(df["Cost"].describe())

print("\nLength of Stay:")
print(df["Length of Stay"].describe())

print("\nSatisfaction:")
print(df["Satisfaction"].describe())
# Out:
# Age:
# count    984.000000
# mean      53.754065
# std       14.941135
# min       25.000000
# 25%       45.000000
# 50%       55.000000
# 75%       65.000000
# max       78.000000
# Name: Age, dtype: float64
#
# Cost:
# count      984.000000
# mean      8367.479675
# std       7761.990976
# min        100.000000
# 25%       1000.000000
# 50%       6000.000000
# 75%      15000.000000
# max      25000.000000
# Name: Cost, dtype: float64
#
# Length of Stay:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# ...

# %%
for i, col in enumerate(df.columns):
    print(i, repr(col))
# Out:
# 0 'Patient_ID'
# 1 'Age'
# 2 'Gender'
# 3 'Condition'
# 4 'Procedure'
# 5 'Cost'
# 6 'Length_of_Stay'
# 7 'Readmission'
# 8 'Outcome'
# 9 'Satisfaction'

# %%
df.columns = df.columns.str.strip()

print(df.columns.tolist())
# Out:
# ['Patient_ID', 'Age', 'Gender', 'Condition', 'Procedure', 'Cost', 'Length_of_Stay', 'Readmission', 'Outcome', 'Satisfaction']

# %%
for col in ["Age", "Cost", "Length of Stay", "Satisfaction"]:
    print(col, "→ Min:", df[col].min(), "| Max:", df[col].max())
# Out:
# Age → Min: 25 | Max: 78
# Cost → Min: 100 | Max: 25000
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
for col in df.columns:
    print(repr(col))
# Out:
# 'Patient_ID'
# 'Age'
# 'Gender'
# 'Condition'
# 'Procedure'
# 'Cost'
# 'Length_of_Stay'
# 'Readmission'
# 'Outcome'
# 'Satisfaction'

# %%
print("Length of Stay → Min:", df["Length of Stay"].min())
print("Length of Stay → Max:", df["Length of Stay"].max())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
print("Length of Stay → Min:", df["Length of Stay"].min())
print("Length of Stay → Max:", df["Length of Stay"].max())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
print(df.columns.tolist())
# Out:
# ['Patient_ID', 'Age', 'Gender', 'Condition', 'Procedure', 'Cost', 'Length_of_Stay', 'Readmission', 'Outcome', 'Satisfaction']

# %%
print("Length of Stay - Min:", df["Length_of_Stay"].min())
print("Length of Stay - Max:", df["Length_of_Stay"].max())
# Out:
# Length of Stay - Min: 1
# Length of Stay - Max: 76

# %%
print("Cost → Min:", df["cost"].min(), "| Max:", df["cost"].max())
print("Satisfaction → Min:", df["satisfaction"].min(), "| Max:", df["satisfaction"].max())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
print("Cost → Min:", df["Cost"].min(), "| Max:", df["Cost"].max())
print("Satisfaction → Min:", df["Satisfaction"].min(), "| Max:", df["Satisfaction"].max())
# Out:
# Cost → Min: 100 | Max: 25000
# Satisfaction → Min: 2 | Max: 5

# %%
text_columns = ["Gender", "Condition", "Procedure", "Readmission", "Outcome"]

for col in text_columns:
    print(f"\n--- {col} ---")
    print(df[col].value_counts())
# Out:
# --- Gender ---
# Gender
# Female    524
# Male      460
# Name: count, dtype: int64
#
# --- Condition ---
# Condition
# Fractured Leg            67
# Heart Attack             67
# Fractured Arm            66
# Stroke                   66
# Cancer                   66
# Hypertension             66
# Appendicitis             66
# Allergic Reaction        66
# Heart Disease            65
# Diabetes                 65
# Respiratory Infection    65
# Prostate Cancer          65
# Childbirth               65
# Kidney Stones            65
# Osteoarthritis           64
# Name: count, dtype: int64
#
# --- Procedure ---
# Procedure
# Cast and Physical Therapy               67
# Cardiac Catheterization                 67
# X-Ray and Splint                        66
# CT Scan and Medication                  66
# Surgery and Chemotherapy                66
# Medication and Counseling               66
# Appendectomy                            66
# Epinephrine Injection                   66
# ...

# %%
print("Procedure:")
print(df["Procedure"].unique())

print("\nReadmission:")
print(df["Readmission"].unique())
# Out:
# Procedure:
# <StringArray>
# [                         'Angioplasty',
#                       'Insulin Therapy',
#                      'X-Ray and Splint',
#                'CT Scan and Medication',
#              'Surgery and Chemotherapy',
#             'Medication and Counseling',
#                          'Appendectomy',
#             'Cast and Physical Therapy',
#               'Cardiac Catheterization',
#                 'Epinephrine Injection',
#                  'Antibiotics and Rest',
#                     'Radiation Therapy',
#           'Delivery and Postnatal Care',
#                           'Lithotripsy',
#  'Physical Therapy and Pain Management']
# Length: 15, dtype: str
#
# Readmission:
# <StringArray>
# ['No', 'Yes']
# Length: 2, dtype: str

# %%
text_columns = ["Gender", "Condition", "Procedure", "Readmission", "Outcome"]

for col in text_columns:
    df[col] = df[col].astype(str).str.strip()

# %%
numeric_columns = ["Age", "Cost", "Length_of_Stay", "Satisfaction"]

for col in numeric_columns:
    df[col] = pd.to_numeric(df[col], errors="coerce")

# %%
print("Missing values:")
print(df.isnull().sum())

print("\nDuplicate rows:", df.duplicated().sum())
# Out:
# Missing values:
# Patient_ID        0
# Age               0
# Gender            0
# Condition         0
# Procedure         0
# Cost              0
# Length_of_Stay    0
# Readmission       0
# Outcome           0
# Satisfaction      0
# dtype: int64
#
# Duplicate rows: 0

# %%
output_path = "../data/cleaned/hospital_cleaned.csv"

df.to_csv(output_path, index=False)

print("Cleaned dataset saved successfully!")
# Out:
# Cleaned dataset saved successfully!
