# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# Load all raw datasets
patients = pd.read_csv("data/raw/patients.csv")
services_weekly = pd.read_csv("data/raw/services_weekly.csv")
staff = pd.read_csv("data/raw/staff.csv")
staff_schedule = pd.read_csv("data/raw/staff_schedule.csv")
hospital_insights_summary = pd.read_csv("data/raw/hospital_insights_summary.csv")

# %%
# ----------------------------------------------------
# PATIENTS.CSV
# ----------------------------------------------------
print(patients.shape)
print(patients.columns)
print(patients.head())
print(patients.info())
print(patients.describe())
# Out:
# (1000, 7)
# Index(['patient_id', 'name', 'age', 'arrival_date', 'departure_date',
#        'service', 'satisfaction'],
#       dtype='str')
#      patient_id               name  age arrival_date departure_date  \
# 0  PAT-09484753  Richard Rodriguez   24   2025-03-16     2025-03-22
# 1  PAT-f0644084     Shannon Walker    6   2025-12-13     2025-12-14
# 2  PAT-ac6162e4       Julia Torres   24   2025-06-29     2025-07-05
# 3  PAT-3dda2bb5    Crystal Johnson   32   2025-10-12     2025-10-23
# 4  PAT-08591375        Garrett Lin   25   2025-02-18     2025-02-25
#
#             service  satisfaction
# 0           surgery            61
# 1           surgery            83
# 2  general_medicine            83
# 3         emergency            81
# 4               ICU            76
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
# ...

# %%
print(patients.isnull().sum())
print(patients.duplicated().sum())
print(patients.nunique())
# Out:
# patient_id        0
# name              0
# age               0
# arrival_date      0
# departure_date    0
# service           0
# satisfaction      0
# dtype: int64
# 0
# patient_id        1000
# name               993
# age                 90
# arrival_date       344
# departure_date     337
# service              4
# satisfaction        40
# dtype: int64

# %%
# ----------------------------------------------------
# SERVICES_WEEKLY.CSV
# ----------------------------------------------------
print(services_weekly.shape)
print(services_weekly.columns)
print(services_weekly.head())
print(services_weekly.info())
print(services_weekly.describe())
# Out:
# (208, 10)
# Index(['week', 'month', 'service', 'available_beds', 'patients_request',
#        'patients_admitted', 'patients_refused', 'patient_satisfaction',
#        'staff_morale', 'event'],
#       dtype='str')
#    week  month           service  available_beds  patients_request  \
# 0     1      1         emergency              32                76
# 1     1      1           surgery              45               130
# 2     1      1  general_medicine              37               201
# 3     1      1               ICU              22                31
# 4     2      1         emergency              28               169
#
#    patients_admitted  patients_refused  patient_satisfaction  staff_morale  \
# 0                 32                44                    67            70
# 1                 45                85                    83            78
# 2                 37               164                    97            43
# ...

# %%
print(services_weekly.isnull().sum())
print(services_weekly.duplicated().sum())
print(services_weekly.nunique())
# Out:
# week                    0
# month                   0
# service                 0
# available_beds          0
# patients_request        0
# patients_admitted       0
# patients_refused        0
# patient_satisfaction    0
# staff_morale            0
# event                   0
# dtype: int64
# 0
# week                     52
# month                    12
# service                   4
# available_beds           56
# patients_request        110
# patients_admitted        56
# patients_refused         80
# patient_satisfaction     40
# staff_morale             55
# event                     4
# dtype: int64

# %%
# ----------------------------------------------------
# STAFF.CSV
# ----------------------------------------------------
print(staff.shape)
print(staff.columns)
print(staff.head())
print(staff.info())
print(staff.describe())
# Out:
# (110, 4)
# Index(['staff_id', 'staff_name', 'role', 'service'], dtype='str')
#        staff_id       staff_name    role    service
# 0  STF-5ca26577     Allison Hill  doctor  emergency
# 1  STF-02ae59ca      Noah Rhodes  doctor  emergency
# 2  STF-d8006e7c  Angie Henderson  doctor  emergency
# 3  STF-212d8b31    Daniel Wagner  doctor  emergency
# 4  STF-107a58e4  Cristian Santos  doctor  emergency
# <class 'pandas.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   staff_id    110 non-null    str
#  1   staff_name  110 non-null    str
#  2   role        110 non-null    str
#  3   service     110 non-null    str
# dtypes: str(4)
# memory usage: 3.6 KB
# None
#             staff_id    staff_name   role service
# count            110           110    110     110
# unique           110           110      3       4
# top     STF-5ca26577  Allison Hill  nurse     ICU
# ...

# %%
print(staff.isnull().sum())
print(staff.duplicated().sum())
print(staff.nunique())
# Out:
# staff_id      0
# staff_name    0
# role          0
# service       0
# dtype: int64
# 0
# staff_id      110
# staff_name    110
# role            3
# service         4
# dtype: int64

# %%
# ----------------------------------------------------
# STAFF_SCHEDULE.CSV
# ----------------------------------------------------
print(staff_schedule.shape)
print(staff_schedule.columns)
print(staff_schedule.head())
print(staff_schedule.info())
print(staff_schedule.describe())
# Out:
# (6552, 6)
# Index(['week', 'staff_id', 'staff_name', 'role', 'service', 'present'], dtype='str')
#    week      staff_id    staff_name    role    service  present
# 0     1  STF-b77cdc60  Allison Hill  doctor  emergency        1
# 1     2  STF-b77cdc60  Allison Hill  doctor  emergency        1
# 2     3  STF-b77cdc60  Allison Hill  doctor  emergency        0
# 3     4  STF-b77cdc60  Allison Hill  doctor  emergency        1
# 4     5  STF-b77cdc60  Allison Hill  doctor  emergency        1
# <class 'pandas.DataFrame'>
# RangeIndex: 6552 entries, 0 to 6551
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   week        6552 non-null   int64
#  1   staff_id    6552 non-null   str
#  2   staff_name  6552 non-null   str
#  3   role        6552 non-null   str
#  4   service     6552 non-null   str
#  5   present     6552 non-null   int64
# dtypes: int64(2), str(4)
# memory usage: 307.3 KB
# None
# ...

# %%
print(staff_schedule.isnull().sum())
print(staff_schedule.duplicated().sum())
print(staff_schedule.nunique())
# Out:
# week          0
# staff_id      0
# staff_name    0
# role          0
# service       0
# present       0
# dtype: int64
# 0
# week           52
# staff_id      126
# staff_name    126
# role            3
# service         4
# present         2
# dtype: int64

# %%
# ----------------------------------------------------
# HOSPITAL_INSIGHTS_SUMMARY.CSV
# ----------------------------------------------------
print(hospital_insights_summary.shape)
print(hospital_insights_summary.columns)
print(hospital_insights_summary.head())
print(hospital_insights_summary.info())
print(hospital_insights_summary.describe())
# Out:
# (208, 8)
# Index(['week', 'service', 'patients_admitted', 'avg_stay', 'avg_satisfaction',
#        'max_occupancy', 'staff_count', 'recommended_staff'],
#       dtype='str')
#    week           service  patients_admitted   avg_stay  avg_satisfaction  \
# 0     1               ICU                  7   5.428571         84.857143
# 1     1         emergency                  4   9.250000         86.000000
# 2     1  general_medicine                  5   7.400000         77.400000
# 3     1           surgery                  6  10.000000         84.666667
# 4     2               ICU                  4   8.000000         69.250000
#
#    max_occupancy  staff_count  recommended_staff
# 0             14           34                2.0
# 1             13           39                1.0
# 2             12           28                1.0
# 3             11           25                2.0
# 4             13           34                1.0
# <class 'pandas.DataFrame'>
# ...

# %%
print(hospital_insights_summary.isnull().sum())
print(hospital_insights_summary.duplicated().sum())
print(hospital_insights_summary.nunique())
# Out:
# week                 0
# service              0
# patients_admitted    0
# avg_stay             0
# avg_satisfaction     0
# max_occupancy        0
# staff_count          0
# recommended_staff    0
# dtype: int64
# 0
# week                  52
# service                4
# patients_admitted     10
# avg_stay              93
# avg_satisfaction     142
# max_occupancy         12
# staff_count            4
# recommended_staff      2
# dtype: int64
